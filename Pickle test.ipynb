# %%
#Basic Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import path
import pickle

# %%
df = pd.read_csv("../Amazon-Review-Predictor/cleaned.csv")

# %%
df.head()
# Out:
#    customer_id       review_id  product_id  product_parent  \
# 0     30739283  R190J2PDOZ5GVK  B00ZDWGFR2       390090468
# 1     15760475  R3SGZ5G1GJAWVU  B00TSR7YPK       515216474
# 2     10861723  R3BWM499VCMGS7  B00ZDWGFR2       390090468
# 3     22343417  R3SMKIWNMR55UB  B00O29LKN6       474362814
# 4       106593   RNBM8M0T11BV0  B009F2OUOQ       968361935
#
#                                        product_title  star_rating  \
# 0  Sony a7R II Full-Frame Mirrorless Interchangea...            3
# 1  Nikon D750 DSLR Camera (Body Only) + 32GB Extr...            5
# 2  Sony a7R II Full-Frame Mirrorless Interchangea...            5
# 3  Canon EOS 7D Mark II Digital SLR Camera (Body ...            5
# 4  Olympus OM-G OMG OM-20 Manual Focus Film Camer...            1
#
#    helpful_votes  total_votes verified_purchase review_date  \
# 0             36           51                 Y  2015-08-31
# 1              1            1                 Y  2015-08-31
# 2             48           52                 Y  2015-08-31
# 3              0            0                 Y  2015-08-29
# 4              3            3                 Y  2015-08-29
#
#                                      review_headline  \
# 0           Great camera, but there are shortcomings
# 1  This camera is amazing, I have a d610 that I r...
# 2                         Absolutly Must have camera
# 3                                      Canon Digital
# 4   This is only for the camera and strap. There ...
#
#                                          review_body  helpful_ratio  \
# 0  Great camera, but there are shortcomings :  -4...       0.705882
# 1  This camera is amazing, I have a d610 that I r...       1.000000
# 2  Im a Canon guy, but as soon as I found out thi...       0.923077
# 3  I read several review's before my purchase.  T...       0.700245
# 4  This is only for the camera and strap. There i...       1.000000
#
#    review_length camera_brand  vader_compound  vader_neg  vader_neu  vader_pos
# 0            199         sony          0.8964      0.103      0.768      0.129
# 1             21        nikon          0.5100      0.000      0.788      0.212
# 2            212         sony          0.9967      0.022      0.707      0.271
# 3             14        canon          0.0000      0.000      1.000      0.000
# 4             33      olympus         -0.6808      0.185      0.815      0.000

# %%
with open('df.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
# TO UPLOAD ANY PICKLE FILE INTO AN OBJECT (dest_object_name)...

with open('df.pkl', 'rb') as f:
    imported_pickle = pickle.load(f)

# %%
imported_pickle.head()
# Out:
#    customer_id       review_id  product_id  product_parent  \
# 0     30739283  R190J2PDOZ5GVK  B00ZDWGFR2       390090468
# 1     15760475  R3SGZ5G1GJAWVU  B00TSR7YPK       515216474
# 2     10861723  R3BWM499VCMGS7  B00ZDWGFR2       390090468
# 3     22343417  R3SMKIWNMR55UB  B00O29LKN6       474362814
# 4       106593   RNBM8M0T11BV0  B009F2OUOQ       968361935
#
#                                        product_title  star_rating  \
# 0  Sony a7R II Full-Frame Mirrorless Interchangea...            3
# 1  Nikon D750 DSLR Camera (Body Only) + 32GB Extr...            5
# 2  Sony a7R II Full-Frame Mirrorless Interchangea...            5
# 3  Canon EOS 7D Mark II Digital SLR Camera (Body ...            5
# 4  Olympus OM-G OMG OM-20 Manual Focus Film Camer...            1
#
#    helpful_votes  total_votes verified_purchase review_date  \
# 0             36           51                 Y  2015-08-31
# 1              1            1                 Y  2015-08-31
# 2             48           52                 Y  2015-08-31
# 3              0            0                 Y  2015-08-29
# 4              3            3                 Y  2015-08-29
#
#                                      review_headline  \
# 0           Great camera, but there are shortcomings
# 1  This camera is amazing, I have a d610 that I r...
# 2                         Absolutly Must have camera
# 3                                      Canon Digital
# 4   This is only for the camera and strap. There ...
#
#                                          review_body  helpful_ratio  \
# 0  Great camera, but there are shortcomings :  -4...       0.705882
# 1  This camera is amazing, I have a d610 that I r...       1.000000
# 2  Im a Canon guy, but as soon as I found out thi...       0.923077
# 3  I read several review's before my purchase.  T...       0.700245
# 4  This is only for the camera and strap. There i...       1.000000
#
#    review_length camera_brand  vader_compound  vader_neg  vader_neu  vader_pos
# 0            199         sony          0.8964      0.103      0.768      0.129
# 1             21        nikon          0.5100      0.000      0.788      0.212
# 2            212         sony          0.9967      0.022      0.707      0.271
# 3             14        canon          0.0000      0.000      1.000      0.000
# 4             33      olympus         -0.6808      0.185      0.815      0.000

# %%
#Models
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

#Preprocessing and metrics
from sklearn.preprocessing import StandardScaler, MaxAbsScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer


from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
y = df.star_rating

# %%
y.value_counts(normalize=True)
# Out:
# 5    0.713547
# 4    0.153104
# 1    0.057385
# 3    0.050094
# 2    0.025870
# Name: star_rating, dtype: float64

# %%
X = df[['review_length','vader_compound']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
lr = LogisticRegression(multi_class='ovr')

# %%
lr_fit = lr.fit(X_train, y_train)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
lr.score(X_train, y_train)
# Out:
# 0.7268145161290323

# %%
with open('lr.pkl', 'wb') as f:
    pickle.dump(lr, f)

# %%
# TO UPLOAD ANY PICKLE FILE INTO AN OBJECT (dest_object_name)...

with open('lr.pkl', 'rb') as f:
    imported_model = pickle.load(f)

# %%
imported_model.score(X_test, y_test)
imported_model.predict(X_train)
# Out:
# array([5, 5, 5, ..., 5, 5, 5])
